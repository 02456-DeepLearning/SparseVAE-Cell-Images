# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 300)
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt
import random

# %%
metadata_path = './bbbc021/singlecell/metadata.csv'
npobj_path = './bbbc021/singlecell/singh_cp_pipeline_singlecell_images/B02_s1_w16F89C55C-7808-4136-82E4-E066F8E3CB10/B02_s1_w16F89C55C-7808-4136-82E4-E066F8E3CB10_0.npy'

# %%
pd.read_csv(metadata_path)['Single_Cell_Image_Name'][0]
# Out:
# 'Week10_200907_B02_s1_w18E215662-2CF7-4739-93F3-DBD0C40B78DB_0.npy'

# %%
npobj = np.load(npobj_path)

# %%
print('IMG dimensions: ', np.shape(npobj))
max_val = np.max(npobj)
# Out:
# IMG dimensions:  (68, 68, 3)

# %%
plt.imshow(npobj/40000)

plt.show()
